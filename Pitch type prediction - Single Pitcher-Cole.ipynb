# %% [markdown]
# # Import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import data

# %%
dataset = pd.read_csv('preprocessed_data_single_cole.csv')
dataset.head()
# Out:
#       px     pz  start_speed  end_speed  spin_rate  spin_dir  break_angle  \
# 0  0.875  2.851         94.2       85.8   2464.304   212.257         35.2
# 1 -0.502  1.781         91.6       84.0   2363.093   217.113         34.7
# 2 -0.992  1.767         87.3       80.6   1589.739   252.360         22.6
# 3 -1.205  1.707         94.0       85.5   2721.306   215.655         44.9
# 4  0.085  2.182         93.0       85.4   2148.959   224.677         32.0
#
#        ax      ay      az  ...    vz0       x     x0       y     z0  pfx_x  \
# 0 -12.473  33.209 -12.412  ... -5.426   83.65 -2.606  161.80  5.704  -6.57
# 1 -13.157  30.069 -14.786  ... -7.154  136.14 -2.769  190.69  5.555  -7.28
# 2 -13.347  26.523 -27.930  ... -3.941  154.81 -2.823  191.07  5.524  -8.07
# 3 -15.029  34.298 -11.225  ... -8.331  162.93 -2.920  192.69  5.565  -7.96
# 4 -14.152  30.557 -17.862  ... -5.826  113.76 -2.707  179.87  5.600  -7.59
#
#    pfx_z  nasty  pitch_type  pitcher_id
# 0  10.37   69.0          FF      543037
# 1   9.58   50.0          FF      543037
# 2   2.52   59.0          CH      543037
# 3  11.06   80.0          FF      543037
# 4   7.64   30.0          FF      543037
#
# [5 rows x 22 columns]

# %%
#Visualize by histogram
dataset.hist(figsize= (30,30))
plt.show()

# %%
#Visualize pitch type
import seaborn as sns
sns.catplot(x="pitch_type", kind="count", palette="ch:.25", data=dataset);
plt.show()

# %%
# Import ependent Variable
X = dataset.iloc[:, 0:19].values

# %%
# Import Dependent Variable
#y = dataset.iloc[0:100000, 29].values
y = dataset.iloc[0:, 20].values

# Encoding the Dependent Variable
from sklearn.preprocessing import LabelEncoder
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)

#convert y into binary format
import keras
from keras.utils import to_categorical
y_binary = to_categorical(y)
# Out:
# Using TensorFlow backend.
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
keys = labelencoder_y.classes_
values = labelencoder_y.transform(labelencoder_y.classes_)
dictionary = dict(zip(keys, values))
print(dictionary)
# Out:
# {'FF': 1, 'FT': 2, 'CH': 0, 'SI': 4, 'KC': 3, 'SL': 5}

# %% [markdown]
# # Split data into trainning set and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_binary, test_size = 0.2)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Importing the Keras libraries and packages
#import keras
import tensorflow as tf
from keras import metrics
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
#Initilize ANN
classifier = Sequential()

#Add input layer and fitst hidden layer
classifier.add(Dense(50, activation='relu', kernel_initializer='uniform', input_dim = 19))


#Add second hidden layer
classifier.add(Dense(50, activation='relu', kernel_initializer='uniform'))

#Add oupt layer
#classifier.add(Dense(10, activation = tf.nn.softmax, kernel_initializer='uniform'))
classifier.add(Dense(6, activation = tf.nn.softmax, kernel_initializer='uniform'))

#compiling ANN
#classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = [metrics.categorical_accuracy])

sgd = keras.optimizers.SGD(0.0025, momentum=0.0, nesterov=False)
classifier.compile(optimizer = sgd, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])

# Fitting the ANN to the Training set
model = classifier.fit(X_train, y_train, batch_size = 10, nb_epoch = 50, validation_split=0.1)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:22: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 8334 samples, validate on 926 samples
# Epoch 1/50
# 8334/8334 [==============================] - 2s 297us/step - loss: 1.6652 - categorical_accuracy: 0.4972 - val_loss: 1.5759 - val_categorical_accuracy: 0.4849
# Epoch 2/50
# 8334/8334 [==============================] - 2s 274us/step - loss: 1.5030 - categorical_accuracy: 0.4964 - val_loss: 1.4588 - val_categorical_accuracy: 0.4849
# Epoch 3/50
# 8334/8334 [==============================] - 3s 316us/step - loss: 1.3490 - categorical_accuracy: 0.4964 - val_loss: 1.2286 - val_categorical_accuracy: 0.4849
# Epoch 4/50
# 8334/8334 [==============================] - 3s 325us/step - loss: 1.0219 - categorical_accuracy: 0.6581 - val_loss: 0.9115 - val_categorical_accuracy: 0.6814
# Epoch 5/50
# 8334/8334 [==============================] - 2s 254us/step - loss: 0.8428 - categorical_accuracy: 0.7661 - val_loss: 0.8297 - val_categorical_accuracy: 0.7538
# Epoch 6/50
# 8334/8334 [==============================] - 2s 253us/step - loss: 0.7861 - categorical_accuracy: 0.7862 - val_loss: 0.7848 - val_categorical_accuracy: 0.8002
# Epoch 7/50
# 8334/8334 [==============================] - 2s 256us/step - loss: 0.7498 - categorical_accuracy: 0.8020 - val_loss: 0.7517 - val_categorical_accuracy: 0.7981
# Epoch 8/50
# 8334/8334 [==============================] - 2s 276us/step - loss: 0.7208 - categorical_accuracy: 0.7943 - val_loss: 0.7233 - val_categorical_accuracy: 0.7981
# Epoch 9/50
# 8334/8334 [==============================] - 2s 248us/step - loss: 0.6957 - categorical_accuracy: 0.7984 - val_loss: 0.6972 - val_categorical_accuracy: 0.7948
# Epoch 10/50
# 8334/8334 [==============================] - 2s 262us/step - loss: 0.6716 - categorical_accuracy: 0.8035 - val_loss: 0.6713 - val_categorical_accuracy: 0.7948
# Epoch 11/50
# 8334/8334 [==============================] - 2s 284us/step - loss: 0.6457 - categorical_accuracy: 0.8062 - val_loss: 0.6429 - val_categorical_accuracy: 0.7959
# Epoch 12/50
# 8334/8334 [==============================] - 2s 283us/step - loss: 0.6159 - categorical_accuracy: 0.8078 - val_loss: 0.6097 - val_categorical_accuracy: 0.7959
# Epoch 13/50
# 8334/8334 [==============================] - 2s 264us/step - loss: 0.5813 - categorical_accuracy: 0.8102 - val_loss: 0.5721 - val_categorical_accuracy: 0.7991
# Epoch 14/50
# 8334/8334 [==============================] - 2s 273us/step - loss: 0.5442 - categorical_accuracy: 0.8113 - val_loss: 0.5348 - val_categorical_accuracy: 0.7991
# Epoch 15/50
# 8334/8334 [==============================] - 2s 297us/step - loss: 0.5091 - categorical_accuracy: 0.8119 - val_loss: 0.5021 - val_categorical_accuracy: 0.8035
# Epoch 16/50
# 8334/8334 [==============================] - 2s 244us/step - loss: 0.4799 - categorical_accuracy: 0.8323 - val_loss: 0.4741 - val_categorical_accuracy: 0.8348
# Epoch 17/50
# 8334/8334 [==============================] - 2s 233us/step - loss: 0.4554 - categorical_accuracy: 0.8522 - val_loss: 0.4526 - val_categorical_accuracy: 0.8467
# Epoch 18/50
# 8334/8334 [==============================] - 2s 237us/step - loss: 0.4353 - categorical_accuracy: 0.8608 - val_loss: 0.4330 - val_categorical_accuracy: 0.8585
# Epoch 19/50
# 8334/8334 [==============================] - 2s 248us/step - loss: 0.4177 - categorical_accuracy: 0.8643 - val_loss: 0.4161 - val_categorical_accuracy: 0.8618
# Epoch 20/50
# 8334/8334 [==============================] - 2s 235us/step - loss: 0.4018 - categorical_accuracy: 0.8671 - val_loss: 0.4004 - val_categorical_accuracy: 0.8639
# Epoch 21/50
# 8334/8334 [==============================] - 2s 235us/step - loss: 0.3871 - categorical_accuracy: 0.8690 - val_loss: 0.3860 - val_categorical_accuracy: 0.8650
# Epoch 22/50
# 8334/8334 [==============================] - 2s 237us/step - loss: 0.3735 - categorical_accuracy: 0.8697 - val_loss: 0.3723 - val_categorical_accuracy: 0.8661
# Epoch 23/50
# 8334/8334 [==============================] - 2s 236us/step - loss: 0.3610 - categorical_accuracy: 0.8709 - val_loss: 0.3600 - val_categorical_accuracy: 0.8672
# Epoch 24/50
# 8334/8334 [==============================] - 2s 232us/step - loss: 0.3495 - categorical_accuracy: 0.8725 - val_loss: 0.3490 - val_categorical_accuracy: 0.8715
# Epoch 25/50
# 8334/8334 [==============================] - 2s 249us/step - loss: 0.3391 - categorical_accuracy: 0.8747 - val_loss: 0.3384 - val_categorical_accuracy: 0.8737
# Epoch 26/50
# 8334/8334 [==============================] - 2s 241us/step - loss: 0.3297 - categorical_accuracy: 0.8775 - val_loss: 0.3290 - val_categorical_accuracy: 0.8737
# Epoch 27/50
# 8334/8334 [==============================] - 2s 235us/step - loss: 0.3213 - categorical_accuracy: 0.8805 - val_loss: 0.3202 - val_categorical_accuracy: 0.8747
# Epoch 28/50
# 8334/8334 [==============================] - 2s 236us/step - loss: 0.3131 - categorical_accuracy: 0.8829 - val_loss: 0.3129 - val_categorical_accuracy: 0.8747
# Epoch 29/50
# 8334/8334 [==============================] - 2s 244us/step - loss: 0.3058 - categorical_accuracy: 0.8871 - val_loss: 0.3045 - val_categorical_accuracy: 0.8780
# Epoch 30/50
# 8334/8334 [==============================] - 2s 242us/step - loss: 0.2986 - categorical_accuracy: 0.8891 - val_loss: 0.2985 - val_categorical_accuracy: 0.8780
# Epoch 31/50
# 8334/8334 [==============================] - 2s 243us/step - loss: 0.2922 - categorical_accuracy: 0.8924 - val_loss: 0.2907 - val_categorical_accuracy: 0.8834
# Epoch 32/50
# 8334/8334 [==============================] - 2s 235us/step - loss: 0.2858 - categorical_accuracy: 0.8957 - val_loss: 0.2833 - val_categorical_accuracy: 0.8888
# Epoch 33/50
# 8334/8334 [==============================] - 2s 257us/step - loss: 0.2795 - categorical_accuracy: 0.8969 - val_loss: 0.2776 - val_categorical_accuracy: 0.8898
# Epoch 34/50
# 8334/8334 [==============================] - ETA: 0s - loss: 0.2732 - categorical_accuracy: 0.90 - 2s 274us/step - loss: 0.2739 - categorical_accuracy: 0.9008 - val_loss: 0.2712 - val_categorical_accuracy: 0.8898
# Epoch 35/50
# 8334/8334 [==============================] - 2s 251us/step - loss: 0.2682 - categorical_accuracy: 0.9020 - val_loss: 0.2657 - val_categorical_accuracy: 0.8942
# Epoch 36/50
# 8334/8334 [==============================] - 3s 304us/step - loss: 0.2624 - categorical_accuracy: 0.9048 - val_loss: 0.2611 - val_categorical_accuracy: 0.8920
# Epoch 37/50
# 8334/8334 [==============================] - 2s 274us/step - loss: 0.2572 - categorical_accuracy: 0.9060 - val_loss: 0.2561 - val_categorical_accuracy: 0.8963
# Epoch 38/50
# 8334/8334 [==============================] - 2s 248us/step - loss: 0.2520 - categorical_accuracy: 0.9095 - val_loss: 0.2497 - val_categorical_accuracy: 0.9060
# Epoch 39/50
# 8334/8334 [==============================] - 3s 307us/step - loss: 0.2470 - categorical_accuracy: 0.9118 - val_loss: 0.2441 - val_categorical_accuracy: 0.9093
# Epoch 40/50
# 8334/8334 [==============================] - 3s 308us/step - loss: 0.2423 - categorical_accuracy: 0.9147 - val_loss: 0.2401 - val_categorical_accuracy: 0.9136
# Epoch 41/50
# 8334/8334 [==============================] - 2s 279us/step - loss: 0.2371 - categorical_accuracy: 0.9182 - val_loss: 0.2355 - val_categorical_accuracy: 0.9179
# Epoch 42/50
# 8334/8334 [==============================] - 2s 237us/step - loss: 0.2322 - categorical_accuracy: 0.9204 - val_loss: 0.2304 - val_categorical_accuracy: 0.9179
# Epoch 43/50
# 8334/8334 [==============================] - 2s 250us/step - loss: 0.2274 - categorical_accuracy: 0.9240 - val_loss: 0.2272 - val_categorical_accuracy: 0.9168
# Epoch 44/50
# 8334/8334 [==============================] - 2s 242us/step - loss: 0.2227 - categorical_accuracy: 0.9240 - val_loss: 0.2228 - val_categorical_accuracy: 0.9233
# Epoch 45/50
# 8334/8334 [==============================] - 2s 255us/step - loss: 0.2180 - categorical_accuracy: 0.9254 - val_loss: 0.2182 - val_categorical_accuracy: 0.9266
# Epoch 46/50
# 8334/8334 [==============================] - 2s 237us/step - loss: 0.2134 - categorical_accuracy: 0.9278 - val_loss: 0.2141 - val_categorical_accuracy: 0.9276
# Epoch 47/50
# 8334/8334 [==============================] - 2s 239us/step - loss: 0.2089 - categorical_accuracy: 0.9269 - val_loss: 0.2104 - val_categorical_accuracy: 0.9309
# Epoch 48/50
# 8334/8334 [==============================] - 3s 334us/step - loss: 0.2050 - categorical_accuracy: 0.9279 - val_loss: 0.2056 - val_categorical_accuracy: 0.9298
# Epoch 49/50
# 8334/8334 [==============================] - 3s 334us/step - loss: 0.2010 - categorical_accuracy: 0.9293 - val_loss: 0.2007 - val_categorical_accuracy: 0.9341
# Epoch 50/50
# 8334/8334 [==============================] - 2s 271us/step - loss: 0.1972 - categorical_accuracy: 0.9303 - val_loss: 0.1983 - val_categorical_accuracy: 0.9352

# %%
def plot_history(histories, key='categorical_crossentropy'):
  plt.figure(figsize=(8,5))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_loss'],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history['loss'], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('tanh', model),
              ('relu', model_small)])

plt.show()

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.35)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
np.savetxt("cm.csv", cm, delimiter=",")

# %%
# Plot non-normalized confusion matrix


class_names = ['CH','FF', 'FT', 'KC','SI','SL',]

#Visualize CM
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    #classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.set_size_inches(19.5, 10.5)
    #fig.tight_layout()
    return ax




#class_names = dataset['CH', 'CU', 'FC', 'FF', 'FS', 'FT', 'KC', 'KN', 'SI', 'SL']
#plot_confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1), classes=class_names, title='Confusion matrix, without normalization')
plot_confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1), classes=class_names, normalize=True,title='Normalized confusion matrix')
plt.show()
# Out:
# Normalized confusion matrix
# [[0.96376812 0.02898551 0.         0.         0.         0.00724638]
#  [0.         0.97608881 0.00768574 0.         0.01622545 0.        ]
#  [0.01612903 0.36290323 0.53225806 0.         0.08870968 0.        ]
#  [0.         0.         0.         0.99333333 0.         0.00666667]
#  [0.         0.22651934 0.06629834 0.         0.70718232 0.        ]
#  [0.         0.00248756 0.         0.00746269 0.         0.99004975]]

# %%
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])

plt.title('Model Loss Progression During Training/Validation')
plt.ylabel('Training and Validation Losses')
plt.xlabel('Epoch Number')
plt.legend(['Training Loss', 'Validation Loss'])

plt.show()

# %%
n_classes = y_test.shape[1]

# Compute ROC curve and ROC area for each class
from sklearn.metrics import roc_curve, auc
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


# Compute macro-average ROC curve and ROC area
from itertools import cycle
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])


plt.figure()
lw = 3
plt.plot(fpr[2], tpr[2], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[2])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
# Compute macro-average ROC curve and ROC area
from itertools import cycle
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize=(12, 8))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['b', 'g', 'r', 'c', 'm', 'y', 'k', 'aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %%
# Compute micro-average ROC curve and ROC area
thresholds = dict()
fpr["micro"], tpr["micro"], thresholds["micro"] = metrics.roc_curve(y_test.ravel(), y_pred.ravel(),pos_label=2)
print(fpr)
print(tpr)
print(thresholds)
